# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f, v, phi = np.genfromtxt("CapacitorNetwork1.txt", usecols = (0, 3, 5), unpack = True)

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1, 2, 1)
plt.plot(f, v)
plt.subplot(1, 2, 2)
plt.plot(f, phi)
plt.show()
